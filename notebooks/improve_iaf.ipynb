# %% [markdown]
# # Improving the IaF Model
# Apparently the IaF model and related code is slower in python than Matlab. Oops.
# Still want to switch -- so this notebook will be used to profile and test performance.

# %%
# So far so good! (There's been use of this code in the past that's deleted for cleanliness)
